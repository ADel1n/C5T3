# %%
#imports
#numpy, pandas, scipy, math, matplotlib
import numpy as np
import pandas as pd
import scipy
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns

#estimators
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import linear_model

#model metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#cross validation
from sklearn.cross_validation import train_test_split
from sklearn.covariance import EmpiricalCovariance

# %%
#Models
modelSVR = SVR()
modelRF = RandomForestRegressor()
modelLR = LinearRegression()

# %%
#data
rawData = pd.read_csv('credit.csv', header=0)
rawData.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0       689         0         0         0         0
# 1      1000      1000      1000         0      2000
# 2      1500      1000      1000      1000      5000
# 3      2019      1200      1100      1069      1000
# 4     36681     10000      9000       689       679
#
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0
#
# [5 rows x 25 columns]

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_1                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# In this dataset there are data that doesn't make sense and questionable. Therefore the data will be subset to remove the data that are "questionable".
#
# Question 1: NO CONSUMPTION in all Pay_Amt columns BUT has Bill AMOUNT??
#
# In below table, you will notice that the subset wherein Pay_amt1 to Pay_Amt6 has value of -2 (no consumption) wherein there are non-zero values on the Bill Amount columns. If the customers did not have any consumption, why would there be any bill amount? Are these bill amounts carry over? From when?

# %%
noConsumption = rawData.query('PAY_1==-2 & PAY_2==-2 & PAY_3==-2 & PAY_4==-2 & PAY_5==-2 & PAY_6==-2')
noConsumption.head()
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 23  24     450000    2          1         1   40     -2     -2     -2     -2
# 33  34     500000    2          2         1   54     -2     -2     -2     -2
# 34  35     500000    1          1         1   58     -2     -2     -2     -2
# 45  46     210000    1          1         2   29     -2     -2     -2     -2
# 52  53     310000    2          2         1   49     -2     -2     -2     -2
#
#                ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 23             ...                    560          0          0     19428
# 33             ...                   7521      71439       8981      4152
# 34             ...                   3180          0       5293      5006
# 45             ...                      0          0          0         0
# 52             ...                  11185       3544        464      7875
#
#     PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 23      1473       560         0         0      1128
# 33     22827      7521     71439       981     51582
# 34     31178      3180         0      5293       768
# 45         0         0         0         0         0
# 52      7600     11185      3544       464         0
#
#     default payment next month
# 23                           1
# 33                           0
# 34                           0
# 45                           1
# 52                           0
#
# [5 rows x 25 columns]

# %%
noConsumption.to_csv('noConsumption.csv')
noConsumption.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2109 entries, 23 to 29985
# Data columns (total 25 columns):
# ID                            2109 non-null int64
# LIMIT_BAL                     2109 non-null int64
# SEX                           2109 non-null int64
# EDUCATION                     2109 non-null int64
# MARRIAGE                      2109 non-null int64
# AGE                           2109 non-null int64
# PAY_1                         2109 non-null int64
# PAY_2                         2109 non-null int64
# PAY_3                         2109 non-null int64
# PAY_4                         2109 non-null int64
# PAY_5                         2109 non-null int64
# PAY_6                         2109 non-null int64
# BILL_AMT1                     2109 non-null int64
# BILL_AMT2                     2109 non-null int64
# BILL_AMT3                     2109 non-null int64
# BILL_AMT4                     2109 non-null int64
# BILL_AMT5                     2109 non-null int64
# BILL_AMT6                     2109 non-null int64
# PAY_AMT1                      2109 non-null int64
# PAY_AMT2                      2109 non-null int64
# PAY_AMT3                      2109 non-null int64
# PAY_AMT4                      2109 non-null int64
# PAY_AMT5                      2109 non-null int64
# PAY_AMT6                      2109 non-null int64
# default payment next month    2109 non-null int64
# dtypes: int64(25)
# memory usage: 508.4 KB

# %% [markdown]
# Question 2: No consumption BUT is defaulting????
#
# In addition to Question 1, below is a graph that depicts what I am considering as questionable data that will need to be verified further with the SME's for this dataset or with the credit default experts in the industry.
#
# As you see in below graph, out of 2109 observations wherein the value is -2 (NO CONSUMPTION) is shown accross all Pay_Amt1 to Pay_Amt6 -- the data is showing that there are 250+ that are considered in "default".

# %%
sns.countplot(x="default payment next month", data=noConsumption)

# %% [markdown]
# Question 3: PAID in FULL in All Pay_Amt Columns but Defaulting?
#
# In this table and below graph,out of 1992 observations wherein the value is -1 (PAID IN FULL) is shown accross all Pay_Amt1 to Pay_Amt6 -- the data is showing that there are 200+ that are considered in "default".

# %%
PaidinFull = rawData.query('PAY_1==-1 & PAY_2==-1 & PAY_3==-1 & PAY_4==-1 & PAY_5==-1 & PAY_6==-1')
PaidinFull.head()
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 21  22     120000    2          2         1   39     -1     -1     -1     -1
# 28  29      50000    2          3         1   47     -1     -1     -1     -1
# 30  31     230000    2          1         2   27     -1     -1     -1     -1
# 48  49     380000    1          2         2   32     -1     -1     -1     -1
# 70  71      80000    1          1         2   31     -1     -1     -1     -1
#
#                ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 21             ...                      0        632        316       316
# 28             ...                   2040      30430        257      3415
# 30             ...                  15339      14307      36923     17270
# 48             ...                  32018      11849      11873     21540
# 70             ...                    390        390        390         0
#
#     PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 21       316         0       632       316         0
# 28      3421      2044     30430       257         0
# 30     13281     15339     14307     37292         0
# 48     15138     24677     11851     11875      8251
# 70       390       390       390       390       390
#
#     default payment next month
# 21                           1
# 28                           0
# 30                           0
# 48                           0
# 70                           0
#
# [5 rows x 25 columns]

# %%
PaidinFull.to_csv('PaidinFull.csv')
PaidinFull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 21 to 29942
# Data columns (total 25 columns):
# ID                            1992 non-null int64
# LIMIT_BAL                     1992 non-null int64
# SEX                           1992 non-null int64
# EDUCATION                     1992 non-null int64
# MARRIAGE                      1992 non-null int64
# AGE                           1992 non-null int64
# PAY_1                         1992 non-null int64
# PAY_2                         1992 non-null int64
# PAY_3                         1992 non-null int64
# PAY_4                         1992 non-null int64
# PAY_5                         1992 non-null int64
# PAY_6                         1992 non-null int64
# BILL_AMT1                     1992 non-null int64
# BILL_AMT2                     1992 non-null int64
# BILL_AMT3                     1992 non-null int64
# BILL_AMT4                     1992 non-null int64
# BILL_AMT5                     1992 non-null int64
# BILL_AMT6                     1992 non-null int64
# PAY_AMT1                      1992 non-null int64
# PAY_AMT2                      1992 non-null int64
# PAY_AMT3                      1992 non-null int64
# PAY_AMT4                      1992 non-null int64
# PAY_AMT5                      1992 non-null int64
# PAY_AMT6                      1992 non-null int64
# default payment next month    1992 non-null int64
# dtypes: int64(25)
# memory usage: 404.6 KB

# %%
sns.countplot(x="default payment next month", data=PaidinFull)

# %%
Revolving = rawData.query('PAY_1==0 & PAY_2==0 & PAY_3==0 & PAY_4==0 & PAY_5==0 & PAY_6==0')
Revolving.head()
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 2    3      90000    2          2         2   34      0      0      0      0
# 3    4      50000    2          2         1   37      0      0      0      0
# 5    6      50000    1          1         2   37      0      0      0      0
# 6    7     500000    1          1         2   29      0      0      0      0
# 14  15     250000    1          1         2   29      0      0      0      0
#
#                ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 2              ...                  14331      14948      15549      1518
# 3              ...                  28314      28959      29547      2000
# 5              ...                  19394      19619      20024      2500
# 6              ...                 542653     483003     473944     55000
# 14             ...                  59696      56875      55512      3000
#
#     PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 2       1500      1000      1000      1000      5000
# 3       2019      1200      1100      1069      1000
# 5       1815       657      1000      1000       800
# 6      40000     38000     20239     13750     13770
# 14      3000      3000      3000      3000      3000
#
#     default payment next month
# 2                            0
# 3                            0
# 5                            0
# 6                            0
# 14                           0
#
# [5 rows x 25 columns]

# %%
Revolving.to_csv('Revolving.csv')
Revolving.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9821 entries, 2 to 29999
# Data columns (total 25 columns):
# ID                            9821 non-null int64
# LIMIT_BAL                     9821 non-null int64
# SEX                           9821 non-null int64
# EDUCATION                     9821 non-null int64
# MARRIAGE                      9821 non-null int64
# AGE                           9821 non-null int64
# PAY_1                         9821 non-null int64
# PAY_2                         9821 non-null int64
# PAY_3                         9821 non-null int64
# PAY_4                         9821 non-null int64
# PAY_5                         9821 non-null int64
# PAY_6                         9821 non-null int64
# BILL_AMT1                     9821 non-null int64
# BILL_AMT2                     9821 non-null int64
# BILL_AMT3                     9821 non-null int64
# BILL_AMT4                     9821 non-null int64
# BILL_AMT5                     9821 non-null int64
# BILL_AMT6                     9821 non-null int64
# PAY_AMT1                      9821 non-null int64
# PAY_AMT2                      9821 non-null int64
# PAY_AMT3                      9821 non-null int64
# PAY_AMT4                      9821 non-null int64
# PAY_AMT5                      9821 non-null int64
# PAY_AMT6                      9821 non-null int64
# default payment next month    9821 non-null int64
# dtypes: int64(25)
# memory usage: 1.9 MB

# %% [markdown]
# Question 4: USE OF REVOLVING CREDIT BUT IN DEFAULT?
#
# In below graph,out of 9,821 observations wherein the value is 0 (USE OF REVOLVING CREDIT) is shown accross all Pay_Amt1 to Pay_Amt6 -- the data is showing that there are 500-1000 that are considered in "default".

# %%
sns.countplot(x="default payment next month", data=Revolving)

# %%
refinedData = pd.concat([rawData, noConsumption, PaidinFull, Revolving]).drop_duplicates(keep=False)
refinedData.to_csv('refinedData.scv')
refinedData.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 4             ...                  20940      19146      19131      2000
# 7             ...                    221       -159        567       380
# 8             ...                  12211      11793       3719      3329
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0       689         0         0         0         0
# 1      1000      1000      1000         0      2000
# 4     36681     10000      9000       689       679
# 7       601         0       581      1687      1542
# 8         0       432      1000      1000      1000
#
#    default payment next month
# 0                           1
# 1                           1
# 4                           0
# 7                           0
# 8                           0
#
# [5 rows x 25 columns]

# %%
refinedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16078 entries, 0 to 29998
# Data columns (total 25 columns):
# ID                            16078 non-null int64
# LIMIT_BAL                     16078 non-null int64
# SEX                           16078 non-null int64
# EDUCATION                     16078 non-null int64
# MARRIAGE                      16078 non-null int64
# AGE                           16078 non-null int64
# PAY_1                         16078 non-null int64
# PAY_2                         16078 non-null int64
# PAY_3                         16078 non-null int64
# PAY_4                         16078 non-null int64
# PAY_5                         16078 non-null int64
# PAY_6                         16078 non-null int64
# BILL_AMT1                     16078 non-null int64
# BILL_AMT2                     16078 non-null int64
# BILL_AMT3                     16078 non-null int64
# BILL_AMT4                     16078 non-null int64
# BILL_AMT5                     16078 non-null int64
# BILL_AMT6                     16078 non-null int64
# PAY_AMT1                      16078 non-null int64
# PAY_AMT2                      16078 non-null int64
# PAY_AMT3                      16078 non-null int64
# PAY_AMT4                      16078 non-null int64
# PAY_AMT5                      16078 non-null int64
# PAY_AMT6                      16078 non-null int64
# default payment next month    16078 non-null int64
# dtypes: int64(25)
# memory usage: 3.2 MB

# %%
corrRefined = refinedData.corr()
print(corrRefined)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.006507  0.007267   0.042711
# LIMIT_BAL                   0.006507   1.000000  0.037719  -0.240635
# SEX                         0.007267   0.037719  1.000000  -0.002558
# EDUCATION                   0.042711  -0.240635 -0.002558   1.000000
# MARRIAGE                   -0.027854  -0.113850 -0.035513  -0.131994
# AGE                         0.019525   0.143759 -0.083191   0.169583
# PAY_1                      -0.003403  -0.251412 -0.056734   0.108498
# PAY_2                       0.019354  -0.306708 -0.078016   0.131144
# PAY_3                       0.006479  -0.292938 -0.070760   0.118039
# PAY_4                       0.029333  -0.266594 -0.061562   0.107526
# PAY_5                      -0.001869  -0.240395 -0.053596   0.087553
# PAY_6                      -0.000462  -0.222301 -0.037167   0.063891
# BILL_AMT1                   0.012472   0.200162 -0.051278   0.028138
# BILL_AMT2                   0.010215   0.190459 -0.044815   0.021056
# BILL_AMT3                   0.012734   0.204719 -0.032221   0.013091
# BILL_AMT4                   0.030604   0.221649 -0.028120  -0.003091
# BILL_AMT5                   0.013591   0.227525 -0.023044  -0.010048
# BILL_AMT6                   0.015321   0.220044 -0.023624  -0.011516
# PAY_AMT1                    0.022710   0.177006  0.005588  -0.034869
# PAY_AMT2                    0.008656   0.179068  0.005387  -0.028983
# PAY_AMT3                    0.045960   0.208503 -0.004296  -0.042139
# PAY_AMT4                    0.017793   0.190736 -0.001142  -0.030316
# PAY_AMT5                    0.000936   0.201444  0.002230  -0.038698
# PAY_AMT6                   -0.002565   0.222245 -0.008971  -0.044786
# default payment next month  0.001013  -0.174474 -0.042234   0.036277
#
#                             MARRIAGE       AGE     PAY_1     PAY_2     PAY_3  \
# ID                         -0.027854  0.019525 -0.003403  0.019354  0.006479
# LIMIT_BAL                  -0.113850  0.143759 -0.251412 -0.306708 -0.292938
# SEX                        -0.035513 -0.083191 -0.056734 -0.078016 -0.070760
# EDUCATION                  -0.131994  0.169583  0.108498  0.131144  0.118039
# MARRIAGE                    1.000000 -0.416215 -0.011425  0.000126  0.013701
# AGE                        -0.416215  1.000000  0.001090 -0.024922 -0.030703
# PAY_1                      -0.011425  0.001090  1.000000  0.553433  0.425859
# PAY_2                       0.000126 -0.024922  0.553433  1.000000  0.696743
# PAY_3                       0.013701 -0.030703  0.425859  0.696743  1.000000
# PAY_4                       0.014194 -0.026779  0.387699  0.564976  0.714748
# PAY_5                       0.017560 -0.033761  0.354512  0.517109  0.600347
# PAY_6                       0.016351 -0.027660  0.318900  0.462876  0.536446
# BILL_AMT1                  -0.041184  0.041673  0.219588  0.271555  0.210235
# BILL_AMT2                  -0.039387  0.039028  0.223510  0.270620  0.262980
# BILL_AMT3                  -0.043941  0.040424  0.198305  0.245018  0.240576
# BILL_AMT4                  -0.037998  0.039407  0.199445  0.244996  0.243810
# BILL_AMT5                  -0.041324  0.037978  0.193809  0.235782  0.233154
# BILL_AMT6                  -0.035223  0.033607  0.188642  0.235501  0.231696
# PAY_AMT1                    0.003402  0.015974 -0.113108 -0.109705  0.001003
# PAY_AMT2                   -0.007182  0.017553 -0.097962 -0.076723 -0.085471
# PAY_AMT3                    0.005064  0.021249 -0.094813 -0.069321 -0.065262
# PAY_AMT4                   -0.010952  0.007584 -0.086447 -0.058023 -0.056415
# PAY_AMT5                    0.003140  0.002233 -0.077211 -0.044372 -0.042708
# PAY_AMT6                   -0.011094  0.017564 -0.080963 -0.045644 -0.045045
# default payment next month -0.037702  0.025799  0.372549  0.300702  0.267528
#
#                                PAY_4             ...              BILL_AMT4  \
# ID                          0.029333             ...               0.030604
# LIMIT_BAL                  -0.266594             ...               0.221649
# SEX                        -0.061562             ...              -0.028120
# EDUCATION                   0.107526             ...              -0.003091
# MARRIAGE                    0.014194             ...              -0.037998
# AGE                        -0.026779             ...               0.039407
# PAY_1                       0.387699             ...               0.199445
# PAY_2                       0.564976             ...               0.244996
# PAY_3                       0.714748             ...               0.243810
# PAY_4                       1.000000             ...               0.258454
# PAY_5                       0.769851             ...               0.287763
# PAY_6                       0.641221             ...               0.271880
# BILL_AMT1                   0.178201             ...               0.770745
# BILL_AMT2                   0.219953             ...               0.823642
# BILL_AMT3                   0.252366             ...               0.872024
# BILL_AMT4                   0.258454             ...               1.000000
# BILL_AMT5                   0.246663             ...               0.915165
# BILL_AMT6                   0.244327             ...               0.861307
# PAY_AMT1                   -0.014037             ...               0.241164
# PAY_AMT2                   -0.005095             ...               0.222089
# PAY_AMT3                   -0.085216             ...               0.347878
# PAY_AMT4                   -0.052415             ...               0.088142
# PAY_AMT5                   -0.039824             ...               0.150560
# PAY_AMT6                   -0.031892             ...               0.170496
# default payment next month  0.253565             ...               0.091218
#
#                             BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID                           0.013591   0.015321  0.022710  0.008656
# LIMIT_BAL                    0.227525   0.220044  0.177006  0.179068
# SEX                         -0.023044  -0.023624  0.005588  0.005387
# EDUCATION                   -0.010048  -0.011516 -0.034869 -0.028983
# MARRIAGE                    -0.041324  -0.035223  0.003402 -0.007182
# AGE                          0.037978   0.033607  0.015974  0.017553
# PAY_1                        0.193809   0.188642 -0.113108 -0.097962
# PAY_2                        0.235782   0.235501 -0.109705 -0.076723
# PAY_3                        0.233154   0.231696  0.001003 -0.085471
# PAY_4                        0.246663   0.244327 -0.014037 -0.005095
# PAY_5                        0.277506   0.269682 -0.010348 -0.006278
# PAY_6                        0.309417   0.304600 -0.004467 -0.008438
# BILL_AMT1                    0.736699   0.713464  0.092647  0.066625
# BILL_AMT2                    0.782717   0.754738  0.292845  0.071949
# BILL_AMT3                    0.814597   0.783747  0.249344  0.389850
# BILL_AMT4                    0.915165   0.861307  0.241164  0.222089
# BILL_AMT5                    1.000000   0.927178  0.214804  0.182920
# BILL_AMT6                    0.927178   1.000000  0.196090  0.176433
# PAY_AMT1                     0.214804   0.196090  1.000000  0.292590
# PAY_AMT2                     0.182920   0.176433  0.292590  1.000000
# PAY_AMT3                     0.302299   0.274276  0.266408  0.248556
# PAY_AMT4                     0.323709   0.280994  0.184422  0.171758
# PAY_AMT5                     0.125972   0.333128  0.139592  0.191603
# PAY_AMT6                     0.152498   0.101638  0.185177  0.165610
# default payment next month   0.092077   0.091573 -0.081395 -0.069138
#
#                             PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ID                          0.045960  0.017793  0.000936 -0.002565
# LIMIT_BAL                   0.208503  0.190736  0.201444  0.222245
# SEX                        -0.004296 -0.001142  0.002230 -0.008971
# EDUCATION                  -0.042139 -0.030316 -0.038698 -0.044786
# MARRIAGE                    0.005064 -0.010952  0.003140 -0.011094
# AGE                         0.021249  0.007584  0.002233  0.017564
# PAY_1                      -0.094813 -0.086447 -0.077211 -0.080963
# PAY_2                      -0.069321 -0.058023 -0.044372 -0.045644
# PAY_3                      -0.065262 -0.056415 -0.042708 -0.045045
# PAY_4                      -0.085216 -0.052415 -0.039824 -0.031892
# PAY_5                       0.016603 -0.071716 -0.039880 -0.027399
# PAY_6                       0.012390  0.030152 -0.058470 -0.031245
# BILL_AMT1                   0.171624  0.149924  0.172087  0.162902
# BILL_AMT2                   0.160319  0.129596  0.152068  0.160625
# BILL_AMT3                   0.120836  0.122211  0.198018  0.178990
# BILL_AMT4                   0.347878  0.088142  0.150560  0.170496
# BILL_AMT5                   0.302299  0.323709  0.125972  0.152498
# BILL_AMT6                   0.274276  0.280994  0.333128  0.101638
# PAY_AMT1                    0.266408  0.184422  0.139592  0.185177
# PAY_AMT2                    0.248556  0.171758  0.191603  0.165610
# PAY_AMT3                    1.000000  0.203016  0.136548  0.157091
# PAY_AMT4                    0.203016  1.000000  0.124058  0.145867
# PAY_AMT5                    0.136548  0.124058  1.000000  0.150527
# PAY_AMT6                    0.157091  0.145867  0.150527  1.000000
# default payment next month -0.065376 -0.073150 -0.066803 -0.073532
#
#                             default payment next month
# ID                                            0.001013
# LIMIT_BAL                                    -0.174474
# SEX                                          -0.042234
# EDUCATION                                     0.036277
# MARRIAGE                                     -0.037702
# AGE                                           0.025799
# PAY_1                                         0.372549
# PAY_2                                         0.300702
# PAY_3                                         0.267528
# PAY_4                                         0.253565
# PAY_5                                         0.247505
# PAY_6                                         0.229031
# BILL_AMT1                                     0.077297
# BILL_AMT2                                     0.087746
# BILL_AMT3                                     0.079955
# BILL_AMT4                                     0.091218
# BILL_AMT5                                     0.092077
# BILL_AMT6                                     0.091573
# PAY_AMT1                                     -0.081395
# PAY_AMT2                                     -0.069138
# PAY_AMT3                                     -0.065376
# PAY_AMT4                                     -0.073150
# PAY_AMT5                                     -0.066803
# PAY_AMT6                                     -0.073532
# default payment next month                    1.000000
#
# [25 rows x 25 columns]

# %%
sns.heatmap(corrRefined, 
            xticklabels=corrRefined.columns.values,
            yticklabels=corrRefined.columns.values)

# %%
covRefined = refinedData.cov()
print(covRefined)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.445166e+07  7.075226e+06    30.757809
# LIMIT_BAL                   7.075226e+06  1.587798e+10  2331.309139
# SEX                         3.075781e+01  2.331309e+03     0.240589
# EDUCATION                   2.852559e+02 -2.346998e+04    -0.000971
# MARRIAGE                   -1.257403e+02 -7.505576e+03    -0.009113
# AGE                         1.556735e+03  1.673889e+05    -0.377060
# PAY_1                      -3.694029e+01 -3.985088e+04    -0.035005
# PAY_2                       2.385518e+02 -5.520638e+04    -0.054662
# PAY_3                       8.043205e+01 -5.310904e+04    -0.049937
# PAY_4                       3.572331e+02 -4.741411e+04    -0.042619
# PAY_5                      -2.203899e+01 -4.139562e+04    -0.035925
# PAY_6                      -5.573127e+00 -3.914173e+04    -0.025474
# BILL_AMT1                   6.525223e+06  1.529376e+09 -1525.123986
# BILL_AMT2                   5.180801e+06  1.410691e+09 -1292.101458
# BILL_AMT3                   6.470214e+06  1.519034e+09  -930.667219
# BILL_AMT4                   1.436837e+07  1.519695e+09  -750.481470
# BILL_AMT5                   6.232486e+06  1.523755e+09  -600.743459
# BILL_AMT6                   6.859119e+06  1.438619e+09  -601.217234
# PAY_AMT1                    3.744403e+06  4.261956e+08    52.378153
# PAY_AMT2                    2.167612e+06  6.548572e+08    76.680131
# PAY_AMT3                    8.333081e+06  5.520736e+08   -44.282089
# PAY_AMT4                    2.819000e+06  4.412979e+08   -10.282685
# PAY_AMT5                    1.345335e+05  4.227715e+08    18.215897
# PAY_AMT6                   -4.049997e+05  5.124629e+08   -80.523276
# default payment next month  4.057315e+00 -1.020042e+04    -0.009611
#
#                                EDUCATION     MARRIAGE            AGE  \
# ID                            285.255873  -125.740251    1556.734689
# LIMIT_BAL                  -23469.977860 -7505.576228  167388.948878
# SEX                            -0.000971    -0.009113      -0.377060
# EDUCATION                       0.599120    -0.053452       1.212924
# MARRIAGE                       -0.053452     0.273722      -2.012184
# AGE                             1.212924    -2.012184      85.386668
# PAY_1                           0.105641    -0.007519       0.012669
# PAY_2                           0.145001     0.000094      -0.328956
# PAY_3                           0.131455     0.010313      -0.408203
# PAY_4                           0.117470     0.010482      -0.349265
# PAY_5                           0.092610     0.012555      -0.426322
# PAY_6                           0.069103     0.011954      -0.357143
# BILL_AMT1                    1320.633082 -1306.511198   23349.602339
# BILL_AMT2                     957.977700 -1211.266952   21198.296478
# BILL_AMT3                     596.687183 -1353.728778   21996.176065
# BILL_AMT4                    -130.193585 -1081.704451   19813.585780
# BILL_AMT5                    -413.344245 -1149.059431   18651.793809
# BILL_AMT6                    -462.494264  -956.124041   16112.574780
# PAY_AMT1                     -515.728731    34.014562    2820.535686
# PAY_AMT2                     -651.082038  -109.053506    4707.277659
# PAY_AMT3                     -685.367870    55.675122    4125.883849
# PAY_AMT4                     -430.853644  -105.205083    1286.667804
# PAY_AMT5                     -498.883465    27.360756     343.725039
# PAY_AMT6                     -634.359879  -106.216466    2969.976264
# default payment next month      0.013028    -0.009152       0.110606
#
#                                    PAY_1         PAY_2         PAY_3  \
# ID                            -36.940288    238.551794     80.432053
# LIMIT_BAL                  -39850.878357 -55206.382422 -53109.044394
# SEX                            -0.035005     -0.054662     -0.049937
# EDUCATION                       0.105641      0.145001      0.131455
# MARRIAGE                       -0.007519      0.000094      0.010313
# AGE                             0.012669     -0.328956     -0.408203
# PAY_1                           1.582375      0.994457      0.770752
# PAY_2                           0.994457      2.040479      1.431968
# PAY_3                           0.770752      1.431968      2.070089
# PAY_4                           0.688349      1.139082      1.451466
# PAY_5                           0.609419      1.009435      1.180395
# PAY_6                           0.560544      0.923914      1.078502
# BILL_AMT1                   16749.349491  23521.162865  18341.449230
# BILL_AMT2                   16526.614666  22722.587406  22240.716146
# BILL_AMT3                   14689.292632  20609.849461  20382.534715
# BILL_AMT4                   13651.241040  19042.271245  19087.121305
# BILL_AMT5                   12957.379788  17900.508828  17828.951440
# BILL_AMT6                   12312.062787  17454.076660  17296.238172
# PAY_AMT1                    -2718.761550  -2994.429799     27.562911
# PAY_AMT2                    -3576.369138  -3180.682345  -3568.952545
# PAY_AMT3                    -2506.157980  -2080.755099  -1973.065268
# PAY_AMT4                    -1996.660973  -1521.830466  -1490.345930
# PAY_AMT5                    -1617.652667  -1055.663458  -1023.417155
# PAY_AMT6                    -1863.681947  -1193.119618  -1185.959310
# default payment next month      0.217434      0.199293      0.178588
#
#                                    PAY_4             ...              \
# ID                            357.233150             ...
# LIMIT_BAL                  -47414.112082             ...
# SEX                            -0.042619             ...
# EDUCATION                       0.117470             ...
# MARRIAGE                        0.010482             ...
# AGE                            -0.349265             ...
# PAY_1                           0.688349             ...
# PAY_2                           1.139082             ...
# PAY_3                           1.451466             ...
# PAY_4                           1.992134             ...
# PAY_5                           1.484898             ...
# PAY_6                           1.264643             ...
# BILL_AMT1                   15251.205816             ...
# BILL_AMT2                   18248.203686             ...
# BILL_AMT3                   20974.974794             ...
# BILL_AMT4                   19848.859444             ...
# BILL_AMT5                   18503.365698             ...
# BILL_AMT6                   17892.409308             ...
# PAY_AMT1                     -378.582150             ...
# PAY_AMT2                     -208.713904             ...
# PAY_AMT3                    -2527.360612             ...
# PAY_AMT4                    -1358.357667             ...
# PAY_AMT5                     -936.182194             ...
# PAY_AMT6                     -823.696934             ...
# default payment next month      0.166049             ...
#
#                                BILL_AMT4     BILL_AMT5     BILL_AMT6  \
# ID                          1.436837e+07  6.232486e+06  6.859119e+06
# LIMIT_BAL                   1.519695e+09  1.523755e+09  1.438619e+09
# SEX                        -7.504815e+02 -6.007435e+02 -6.012172e+02
# EDUCATION                  -1.301936e+02 -4.133442e+02 -4.624943e+02
# MARRIAGE                   -1.081704e+03 -1.149059e+03 -9.561240e+02
# AGE                         1.981359e+04  1.865179e+04  1.611257e+04
# PAY_1                       1.365124e+04  1.295738e+04  1.231206e+04
# PAY_2                       1.904227e+04  1.790051e+04  1.745408e+04
# PAY_3                       1.908712e+04  1.782895e+04  1.729624e+04
# PAY_4                       1.984886e+04  1.850337e+04  1.789241e+04
# PAY_5                       2.139732e+04  2.015538e+04  1.912143e+04
# PAY_6                       2.067152e+04  2.297908e+04  2.208358e+04
# BILL_AMT1                   2.542958e+09  2.374174e+09  2.244632e+09
# BILL_AMT2                   2.634291e+09  2.445255e+09  2.301794e+09
# BILL_AMT3                   2.794049e+09  2.549424e+09  2.394560e+09
# BILL_AMT4                   2.960654e+09  2.646556e+09  2.431589e+09
# BILL_AMT5                   2.646556e+09  2.824722e+09  2.556757e+09
# BILL_AMT6                   2.431589e+09  2.556757e+09  2.692010e+09
# PAY_AMT1                    2.507437e+08  2.181488e+08  1.944097e+08
# PAY_AMT2                    3.507126e+08  2.821494e+08  2.656730e+08
# PAY_AMT3                    3.977484e+08  3.376069e+08  2.990295e+08
# PAY_AMT4                    8.805949e+07  3.158961e+08  2.676929e+08
# PAY_AMT5                    1.364449e+08  1.115104e+08  2.878742e+08
# PAY_AMT6                    1.697617e+08  1.483147e+08  9.649962e+07
# default payment next month  2.302846e+03  2.270530e+03  2.204414e+03
#
#                                 PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# ID                          3.744403e+06  2.167612e+06  8.333081e+06
# LIMIT_BAL                   4.261956e+08  6.548572e+08  5.520736e+08
# SEX                         5.237815e+01  7.668013e+01 -4.428209e+01
# EDUCATION                  -5.157287e+02 -6.510820e+02 -6.853679e+02
# MARRIAGE                    3.401456e+01 -1.090535e+02  5.567512e+01
# AGE                         2.820536e+03  4.707278e+03  4.125884e+03
# PAY_1                      -2.718762e+03 -3.576369e+03 -2.506158e+03
# PAY_2                      -2.994430e+03 -3.180682e+03 -2.080755e+03
# PAY_3                       2.756291e+01 -3.568953e+03 -1.973065e+03
# PAY_4                      -3.785822e+02 -2.087139e+02 -2.527361e+03
# PAY_5                      -2.702224e+02 -2.489978e+02  4.767618e+02
# PAY_6                      -1.192830e+02 -3.421966e+02  3.638089e+02
# BILL_AMT1                   1.073464e+08  1.172466e+08  2.186760e+08
# BILL_AMT2                   3.289223e+08  1.227400e+08  1.980174e+08
# BILL_AMT3                   2.805647e+08  6.662529e+08  1.495190e+08
# BILL_AMT4                   2.507437e+08  3.507126e+08  3.977484e+08
# BILL_AMT5                   2.181488e+08  2.821494e+08  3.376069e+08
# BILL_AMT6                   1.944097e+08  2.656730e+08  2.990295e+08
# PAY_AMT1                    3.651289e+08  1.622605e+08  1.069690e+08
# PAY_AMT2                    1.622605e+08  8.422864e+08  1.515801e+08
# PAY_AMT3                    1.069690e+08  1.515801e+08  4.415447e+08
# PAY_AMT4                    6.470478e+07  9.152688e+07  7.832832e+07
# PAY_AMT5                    4.442605e+07  9.261595e+07  4.778886e+07
# PAY_AMT6                    6.475052e+07  8.795253e+07  6.040491e+07
# default payment next month -7.216195e+02 -9.309704e+02 -6.373765e+02
#
#                                 PAY_AMT4      PAY_AMT5      PAY_AMT6  \
# ID                          2.819000e+06  1.345335e+05 -4.049997e+05
# LIMIT_BAL                   4.412979e+08  4.227715e+08  5.124629e+08
# SEX                        -1.028269e+01  1.821590e+01 -8.052328e+01
# EDUCATION                  -4.308536e+02 -4.988835e+02 -6.343599e+02
# MARRIAGE                   -1.052051e+02  2.736076e+01 -1.062165e+02
# AGE                         1.286668e+03  3.437250e+02  2.969976e+03
# PAY_1                      -1.996661e+03 -1.617653e+03 -1.863682e+03
# PAY_2                      -1.521830e+03 -1.055663e+03 -1.193120e+03
# PAY_3                      -1.490346e+03 -1.023417e+03 -1.185959e+03
# PAY_4                      -1.358358e+03 -9.361822e+02 -8.236969e+02
# PAY_5                      -1.799491e+03 -9.077041e+02 -6.851581e+02
# PAY_6                       7.735918e+02 -1.360778e+03 -7.989426e+02
# BILL_AMT1                   1.669196e+08  1.737948e+08  1.807563e+08
# BILL_AMT2                   1.398702e+08  1.488759e+08  1.727734e+08
# BILL_AMT3                   1.321366e+08  1.942093e+08  1.928733e+08
# BILL_AMT4                   8.805949e+07  1.364449e+08  1.697617e+08
# BILL_AMT5                   3.158961e+08  1.115104e+08  1.483147e+08
# BILL_AMT6                   2.676929e+08  2.878742e+08  9.649962e+07
# PAY_AMT1                    6.470478e+07  4.442605e+07  6.475052e+07
# PAY_AMT2                    9.152688e+07  9.261595e+07  8.795253e+07
# PAY_AMT3                    7.832832e+07  4.778886e+07  6.040491e+07
# PAY_AMT4                    3.371342e+08  3.793853e+07  4.901080e+07
# PAY_AMT5                    3.793853e+07  2.774005e+08  4.587758e+07
# PAY_AMT6                    4.901080e+07  4.587758e+07  3.348616e+08
# default payment next month -6.231647e+02 -5.162224e+02 -6.243060e+02
#
#                             default payment next month
# ID                                            4.057315
# LIMIT_BAL                                -10200.422626
# SEX                                          -0.009611
# EDUCATION                                     0.013028
# MARRIAGE                                     -0.009152
# AGE                                           0.110606
# PAY_1                                         0.217434
# PAY_2                                         0.199293
# PAY_3                                         0.178588
# PAY_4                                         0.166049
# PAY_5                                         0.156929
# PAY_6                                         0.148486
# BILL_AMT1                                  2174.629625
# BILL_AMT2                                  2393.037810
# BILL_AMT3                                  2184.469172
# BILL_AMT4                                  2302.846483
# BILL_AMT5                                  2270.529595
# BILL_AMT6                                  2204.413981
# PAY_AMT1                                   -721.619467
# PAY_AMT2                                   -930.970417
# PAY_AMT3                                   -637.376532
# PAY_AMT4                                   -623.164658
# PAY_AMT5                                   -516.222383
# PAY_AMT6                                   -624.305986
# default payment next month                    0.215267
#
# [25 rows x 25 columns]

# %%
variableName = refinedData.iloc[:,0:4]
variableName.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION
# 0   1      20000    2          2
# 1   2     120000    2          2
# 4   5      50000    1          2
# 7   8     100000    2          2
# 8   9     140000    2          3

# %%
#features
features = refinedData.iloc[:,12:23]
print('Summary of feature sample')
features.head()
# Out:
# Summary of feature sample
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 4       8617       5670      35835      20940      19146      19131      2000
# 7      11876        380        601        221       -159        567       380
# 8      11285      14096      12108      12211      11793       3719      3329
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 4     36681     10000      9000       689
# 7       601         0       581      1687
# 8         0       432      1000      1000

# %%
#dependent variable
depVar = refinedData['default payment next month']

# %%
#Training Set (Feature Space: X Training)
x_train = (features[: 1000])
x_train.head()
# Out:
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 4       8617       5670      35835      20940      19146      19131      2000
# 7      11876        380        601        221       -159        567       380
# 8      11285      14096      12108      12211      11793       3719      3329
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 4     36681     10000      9000       689
# 7       601         0       581      1687
# 8         0       432      1000      1000

# %%
#Dependent Variable Training Set (y Training)
y_train = depVar[: 1000]
y_train_count = len(y_train.index)
print('The number of observations in the Y training set are:',str(y_train_count))
y_train.head()
# Out:
# The number of observations in the Y training set are: 1000
# 0    1
# 1    1
# 4    0
# 7    0
# 8    0
# Name: default payment next month, dtype: int64

# %%
#Testing Set (x Testing)
x_test = features[-100:]
x_test_count = len(x_test.index)
print('The number of observations in the feature testing set is:',str(x_test_count))
x_test.head()
# Out:
# The number of observations in the feature testing set is: 100
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 29816      97841      94992      87801      81545      51338      50826
# 29817      11058      12479      13876      13444      13367      13282
# 29819      20528      16287       7415          0          0          0
# 29820     396343     394858     395716     385947     305542     271385
# 29821     100862        367      15272      12925      75667      67609
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 29816         0       639         0     50918      2000
# 29817      2000      2000      1000      1000      1000
# 29819      1300      1000         0         0         0
# 29820    423903     15100     14600     13000      9500
# 29821       367     16652     76146     67697     67609

# %%
#Ground Truth (y_test)
y_test = features[:-100]
y_test_count = len(y_test.index)
print('The number of observations in the Y training set is:',str(y_test_count))
y_test.head()
# Out:
# The number of observations in the Y training set is: 15978
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 4       8617       5670      35835      20940      19146      19131      2000
# 7      11876        380        601        221       -159        567       380
# 8      11285      14096      12108      12211      11793       3719      3329
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 4     36681     10000      9000       689
# 7       601         0       581      1687
# 8         0       432      1000      1000

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train)
x_train.shape, x_test.shape
# Out:
# ((750, 11), (250, 11))

# %%
model = LinearRegression(n_jobs=10)

# %%
#dependent variable
print(depVar)
# Out:
# 0        1
# 1        1
# 4        0
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13       1
# 15       0
# 16       1
# 17       0
# 18       0
# 19       0
# 20       0
# 22       1
# 24       0
# 26       1
# 31       1
# 35       0
# 37       0
# 38       1
# 39       0
# 44       0
# 46       1
# 47       1
# 50       1
# 53       0
# 54       0
#         ..
# 29953    0
# 29954    0
# 29955    0
# 29956    0
# 29957    0
# 29958    0
# 29959    0
# 29962    0
# 29963    0
# 29964    0
# 29966    1
# 29967    0
# 29968    0
# 29970    0
# 29972    0
# 29973    1
# 29974    1
# 29975    0
# 29976    1
# 29981    0
# 29984    0
# 29986    0
# 29989    0
# 29991    1
# 29992    0
# 29993    0
# 29994    1
# 29996    0
# 29997    1
# 29998    1
# Name: default payment next month, Length: 16078, dtype: int64

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=10, normalize=False)

# %%
modelRF.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
modelSVR.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
modelLR.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(cross_val_score(modelRF, x_train, y_train))
# Out:
# [ 0.03487548 -0.00467378 -0.08831331]

# %%
#Model Fitting
modelRF.fit(x_train,y_train)
print(cross_val_score(modelRF, x_train, y_train))
modelRF.score(x_train,y_train)
# Out:
# [ 0.03226278 -0.04126361 -0.08392638]
# 0.7846666047372681

# %%
modelSVR.fit(x_train,y_train)
print(cross_val_score(modelSVR, x_train, y_train))
modelSVR.score(x_train,y_train)
# Out:
# [ 0.01746271  0.00688289 -0.01805646]
# 0.898987063999611

# %%
modelLR.fit(x_train,y_train)
print(cross_val_score(modelLR, x_train, y_train))
modelLR.score(x_train,y_train)
# Out:
# [-0.01719555  0.01679512  0.02418445]
# 0.05418726028006216

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

# %%
predictions = modelRF.predict(x_test)
predRsquared = r2_score(y_test,predictions)
rmse = sqrt(mean_squared_error(y_test, predictions))
print('R Squared: %.3f' % predRsquared)
print('RSME: %.3f' % rmse)
# Out:
# R Squared: -0.058
# RSME: 0.470

# %%
plt.scatter(y_test, predictions, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show()
